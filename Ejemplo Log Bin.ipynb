# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
Tau=np.random.pareto(1.5,200000)
print(Tau)
# Out:
# [0.69451608 0.45453876 0.39601325 ... 0.48879498 1.09628826 1.43125454]

# %%
min(Tau)
# Out:
# 1.2618351934445826e-06

# %%
max(Tau)
# Out:
# 1657.9332696660701

# %%
np.linspace(-3, 4, 100)
X=10**np.linspace(-3, 4, 100)
plt.loglog(X,X,'k.')

# %%
vals,base=np.histogram(Tau,bins=10**np.linspace(-3,4,51),density=True)

# %%
print(base)
# Out:
# [1.00000000e-03 1.38038426e-03 1.90546072e-03 2.63026799e-03
#  3.63078055e-03 5.01187234e-03 6.91830971e-03 9.54992586e-03
#  1.31825674e-02 1.81970086e-02 2.51188643e-02 3.46736850e-02
#  4.78630092e-02 6.60693448e-02 9.12010839e-02 1.25892541e-01
#  1.73780083e-01 2.39883292e-01 3.31131121e-01 4.57088190e-01
#  6.30957344e-01 8.70963590e-01 1.20226443e+00 1.65958691e+00
#  2.29086765e+00 3.16227766e+00 4.36515832e+00 6.02559586e+00
#  8.31763771e+00 1.14815362e+01 1.58489319e+01 2.18776162e+01
#  3.01995172e+01 4.16869383e+01 5.75439937e+01 7.94328235e+01
#  1.09647820e+02 1.51356125e+02 2.08929613e+02 2.88403150e+02
#  3.98107171e+02 5.49540874e+02 7.58577575e+02 1.04712855e+03
#  1.44543977e+03 1.99526231e+03 2.75422870e+03 3.80189396e+03
#  5.24807460e+03 7.24435960e+03 1.00000000e+04]

# %%
plt.loglog(base[1::],vals,'rx')
X=10**np.array([0.5,3.5])
plt.loglog(X,2*X**(-2.5),'k--')#ley de potencias
